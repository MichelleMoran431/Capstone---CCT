# %%
import numpy as np
import pandas as pd

# %%
uploaded = pd.read_csv('Bev Base Dearation Data Extract .csv')
# Dataset is now stored in a Pandas Dataframe

# %%
uploaded.head()
# Out:
#        SKU                           SKU_DESCRIPTION    BATCHID  \
# 0  1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 1  1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 2  1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 3  1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 4  1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
#
#                                               Recipe  Tank      Unit  \
# 0  10166969:P_BBS25_50171888_00\EM_25MT_NOGUM_SEQ...  U_25  U_25MT03
# 1  10166969:P_BBS25_50171888_00\EM_25MT_NOGUM_SEQ...  U_25  U_25MT03
# 2  10166969:P_BBS25_50171888_00\EM_25MT_NOGUM_SEQ...  U_25  U_25MT03
# 3  10166969:P_BBS25_50171888_00\EM_25MT_NOGUM_SEQ...  U_25  U_25MT03
# 4  10166969:P_BBS25_50171888_00\EM_25MT_NOGUM_SEQ...  U_25  U_25MT03
#
#               Instruction_Step       Source Material_ID  \
# 0         S3_BATCH_IN_PROGRESS  TANK_STATUS         NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
correlation_matrix = uploaded.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Or rename the existing DataFrame (rather than creating a copy)
uploaded.rename(columns={'SKU': 'Material','Deaeration Phase':'Deaeration_Phase'}, inplace=True)

# %%
#Select all the rows where the material is in the list below
Source = ['AGITATION']
df_filtered1 = uploaded[uploaded['Source'].isin(Source)]
print(df_filtered1)
# Out:
#       Material                           SKU_DESCRIPTION    BATCHID  \
# 8      1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 9      1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 10     1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 21     1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107643491
# 32     1002150  BCH Q-CI-5.12/.201/CI/Q54.00/V-54.10 P2B  107762133
# ...        ...                                       ...        ...
# 9456   3044756                         BCH LE/B-12.00 P2  108041496
# 9469   3055706                      BCH LE/A/B-809.00 P2  107737576
# 9471   3055706                      BCH LE/A/B-809.00 P2  107737576
# 9473   3055706                      BCH LE/A/B-809.00 P2  107737576
# 9484   3055706                      BCH LE/A/B-809.00 P2  107737576
#
#                                                  Recipe  Tank      Unit  \
# 8     10166969:P_BBS25_50171888_00\EM_25MT_NOGUM_SEQ...  U_25  U_25MT03
# ...

# %%
# Filter the df vy the most commonly produced material 1775253 in terms of the deaeration phase
df_filtered2 = uploaded[(uploaded['Material'] == 1775253)]
print(df_filtered2)
# Out:
#       Material      SKU_DESCRIPTION    BATCHID  \
# 6250   1775253  BCH OR/B-1580.00 P2  107569832
# 6251   1775253  BCH OR/B-1580.00 P2  107569832
# 6252   1775253  BCH OR/B-1580.00 P2  107569832
# 6253   1775253  BCH OR/B-1580.00 P2  107569832
# 6254   1775253  BCH OR/B-1580.00 P2  107569832
# ...        ...                  ...        ...
# 8015   1775253  BCH OR/B-1580.00 P2  108084747
# 8016   1775253  BCH OR/B-1580.00 P2  108084747
# 8017   1775253  BCH OR/B-1580.00 P2  108084747
# 8018   1775253  BCH OR/B-1580.00 P2  108084747
# 8019   1775253  BCH OR/B-1580.00 P2  108084747
#
#                                                  Recipe  Tank      Unit  \
# 6250  10165351:P_BBS23_50140245_00\EM_23MT_SEQ1_UP:1...  U_23  U_23MT02
# 6251  10165351:P_BBS23_50140245_00\EM_23MT_SEQ1_UP:1...  U_23  U_23MT02
# 6252  10165351:P_BBS23_50140245_00\EM_23MT_SEQ1_UP:1...  U_23  U_23MT02
# 6253  10165351:P_BBS23_50140245_00\EM_23MT_SEQ1_UP:1...  U_23  U_23MT02
# ...

# %%
# Grouping and summing the data per material
df_filtered3 = uploaded.groupby(['BATCHID','Flowrate_KGMIN']).sum()

print(df_filtered3)
# Out:
#                           Material  Quantity  Phase_duration  \
# BATCHID   Flowrate_KGMIN
# 107548283 0.0              7520448       0.0              91
# 107548288 0.0              4824616       0.0              60
# 107548331 0.0              4701585       0.0              91
# 107553570 0.0              6794088       0.0             135
# 107553571 0.0              4945911       0.0              51
# ...                            ...       ...             ...
# 108084747 0.0              5325759       0.0              90
# 108084749 0.0              4701585       0.0              91
# 108084750 0.0              4562952       0.0              92
# 108084758 0.0              7501872       0.0              50
# 108091251 0.0              4691676       0.0              61
#
#                           Phase_start_delay  Phase_row_no  Target_Flowrate  \
# BATCHID   Flowrate_KGMIN
# 107548283 0.0                             0            52              0.0
# ...

# %%
# Or rename the existing DataFrame (rather than creating a copy)
df_filtered4.rename(columns={'SKU': 'Material','Deaeration Phase':'Deaeration_Phase'}, inplace=True)
