# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelleMoran431/Capstone---CCT/blob/main/EDA_PART_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9529eaae-c688-41e3-bca8-66f34f8475a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9529eaae-c688-41e3-bca8-66f34f8475a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
uploaded = pd.read_csv(io.BytesIO(uploaded['Bev Base Dearation Data Extract  (1).csv']),encoding= 'unicode_escape')
# Dataset is now stored in a Pandas Dataframe

# %%
uploaded.tail()
# Out:
#           SKU       SKU_DESCRIPTION    BATCHID  \
# 9482  3055706  BCH LE/A/B-809.00 P2  107737576
# 9483  3055706  BCH LE/A/B-809.00 P2  107737576
# 9484  3055706  BCH LE/A/B-809.00 P2  107737576
# 9485  3055706  BCH LE/A/B-809.00 P2  107737576
# 9486  3055706  BCH LE/A/B-809.00 P2  107737576
#
#                                                  Recipe  Tank      Unit  \
# 9482  10168893:P_BBS24_50212314_00\EM_QA_25MT_UP:1\E...  U_25  U_25MT02
# 9483  10168893:P_BBS24_50212314_00\EM_QA_25MT_UP:1\E...  U_25  U_25MT02
# 9484  10168893:P_BBS24_50212314_00\EM_QA_25MT_UP:1\E...  U_25  U_25MT02
# 9485  10168893:P_BBS24_50212314_00\EM_QA_25MT_UP:1\F...  U_25  U_25MT02
# 9486  10168893:P_BBS24_50212314_00\EM_QA_25MT_UP:1\F...  U_25  U_25MT02
#
#                                    Instruction_Step       Source Material_ID  \
# 9482               TAKE A SAMPLE AND SUBMIT FOR QA.       PROMPT         NaN
# 9483  SAMPLE TO LAB. RESULTS OK? (NO TO HOMOGENISE)       PROMPT         NaN
# ...

# %%
# Or rename the existing DataFrame (rather than creating a copy)
uploaded.rename(columns={'SKU': 'Material'}, inplace=True)

# %%
uploaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9487 entries, 0 to 9486
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Material               9487 non-null   int64
#  1   SKU_DESCRIPTION        9487 non-null   object
#  2   BATCHID                9487 non-null   int64
#  3   Recipe                 9487 non-null   object
#  4   Tank                   9487 non-null   object
#  5   Unit                   9487 non-null   object
#  6   Instruction_Step       9462 non-null   object
#  7   Source                 9487 non-null   object
#  8   Material_ID            2443 non-null   object
#  9   Material_Name          1980 non-null   object
#  10  Quantity               9487 non-null   float64
#  11  Phase_start            9487 non-null   object
#  12  Phase_end              9487 non-null   object
#  13  Phase_duration         9487 non-null   int64
# ...

# %%
uploaded.describe().T
# Out:
#                         count          mean            std           min  \
# Material               9487.0  1.607941e+06  395642.390058  1.002150e+06
# BATCHID                9487.0  1.078345e+08  153446.483019  1.075483e+08
# Quantity               9487.0  1.114388e+03    3550.912601  0.000000e+00
# Phase_duration         9487.0  3.827501e+01     132.431479  0.000000e+00
# Phase_start_delay      9487.0  6.400401e+01     438.024750  0.000000e+00
# Phase_row_no           9487.0  8.521450e+00       6.312805  1.000000e+00
# Flowrate_KGMIN         9487.0  3.497168e+01     143.649431  0.000000e+00
# Target_Flowrate        3108.0  1.377210e+02     228.811394  4.488600e+00
# Target_Phase_duration  9487.0  2.248656e+01      45.997016  0.000000e+00
# Phase_overrun          7363.0  2.262434e+01     140.615438  0.000000e+00
# Deaeration Phase       9487.0  2.983029e-02       0.170128  0.000000e+00
#
#                                 25%           50%           75%           max
# ...

# %%
uploaded.describe(include='object')
# Out:
#             SKU_DESCRIPTION                   Recipe  Tank      Unit  \
# count                  9487                     9487  9487      9487
# unique                   47                     8141     4        18
# top     BCH OR/B-1580.00 P2  SELECT_DESTINATION_TANK  U_25  U_25MT04
# freq                   1770                      672  3917      1343
#
#        Instruction_Step  Source Material_ID  Material_Name       Phase_start  \
# count              9462    9487        2443           1980              9487
# unique               29       5         116             40              7552
# top          STEP1_CONS  PROMPT     1002565  WATER TREATED  24/02/2022 03:29
# freq               1924    2584         699            699                 5
#
#                Phase_end Batch_Phase_Type
# count               9487             9487
# unique              7918               11
# top     16/10/2022 22:45      Tank status
# freq                   4             1779

# %%
Material=uploaded.Material_Name.value_counts()
Material
# Out:
# WATER TREATED                               699
# S651     CITRIC ACID ANH    BG XFX25        318
# S501A                       BG XFX500       222
# S501A                       BG ZFZ20        191
# S811     POTASS SORBATE        ZZX25        156
# S813     SOD BENZOATE          XFX25        153
# S7532.1  COLOR B-CAR           XFX5          30
# S736     CLR FDC YLLOW#6       HFX25         28
# S5183                       BG XFX500        26
# S2255.1                        ZFX226.8      16
# CSOB11                         ZFX177        16
# BCH OR/B-1580.00 P2                          14
# S737     CLR QUINOLINE        GHFX20         14
# S5183                       BG XZX25         11
# BCH #69N  (A-90063)                          10
# S740     CLR FDC RED 40        HFX20          9
# S827     ASCORBIC ACID         XZX25          8
# BCH OR-1273.00/OR-1273.01 P2                  8
# PA/LI-1.00/ST/KW-11.00 P2A 10UN 20L DRM       7
# BCH OR-1444.00/.01 P2                         6
# ...

# %%
SKU_DESCRIPTION	=uploaded.SKU_DESCRIPTION	.value_counts()
SKU_DESCRIPTION
# Out:
# BCH OR/B-1580.00 P2                         1770
# BCH OR-1273.00/OR-1273.01 P2                 590
# BCH PF-55.00/.10/.20 P2A                     525
# BCH #69N  (A-90063)                          451
# BCH OR-1193.00 P2                            450
# BCH PR-49.00 P2D                             405
# BCH LE/A/B-623.00/.10 P2                     360
# BCH LE/D-718.50 P2                           351
# BCH LE/B-12.00 P2                            348
# BCH LE/SI-1.00 CB/HB/B-1.00 P2A =1036077     286
# BCH OR-1444.00/.01 P2                        283
# BCH OR/D/6-626.50 P2                         276
# BCH LE/A/D-618.50/LE/A-618.00/LE/A/B P2      254
# BCH SP/E-154.00/SP/D/E-154.50-G P2           244
# BCH MFI ORANGE  SUBASSEMBLY1 SH              207
# BCH OR/Q-698.00/.01/.20/.30/.73/.90 P2       207
# BCH OR-709.00/01 P2                          195
# BCH OR-1327.00/OR-1413.00 P2                 186
# BCH OR/B/6-1072.30 P2                        162
# ...

# %%
Material	=uploaded.Material		.value_counts()
Material
# Out:
# 1775253    1770
# 1520984     590
# 1428047     525
# 1172415     451
# 1451710     450
# 1779699     405
# 1698522     360
# 1985101     351
# 3044756     348
# 1172919     286
# 1648637     283
# 1397022     276
# 1648718     267
# 1688915     254
# 1756358     244
# 1036590     207
# 1045448     195
# 1567195     186
# 1875468     162
# 1002150     159
# 1206154     159
# 1172898     157
# 1418373     140
# 1667507     124
# 1529065     114
# 1451704      87
# 1368236      85
# 1002373      79
# 1529056      78
# 1880112      76
# 1006884      75
# 1399322      73
# 1529244      50
# 1521498      50
# 1552603      48
# 1607495      47
# 1974017      47
# 3055706      28
# 1172993      27
# 1486042      25
# 1513667      25
# 1527533      25
# 3041211      25
# 1668834      25
# 1778314      25
# 1290229      24
# Name: Material, dtype: int64

# %%
from google.colab import files
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-257cb499-e85f-42f0-ad56-fc4c02c750ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-257cb499-e85f-42f0-ad56-fc4c02c750ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
uploaded2 = pd.read_csv(io.BytesIO(uploaded2['Combined mucilage batches (1).csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
uploaded2.head()
# Out:
#    Purchasing Document        System Status  Short-term charac.  \
# 0                  NaN       INSP RREC SPRQ                   2
# 1                  NaN       UD   ICCO STUP                   0
# 2                  NaN  UD   ICCO SPCO STUP                   0
# 3                  NaN       UD   ICCO STUP                   0
# 4                  NaN  UD   ICCO SPCO STUP                   0
#
#    Inspection Lot  Material Document  Material       Batch  \
# 0     40003260779       6.026331e+09   1172919  12752330.0
# 1     30004776790                NaN   1172919  12752330.0
# 2     40003258029       6.026316e+09   1172919  12739990.0
# 3     30004772491                NaN   1172919  12739990.0
# 4     40003252020       6.026273e+09   1172919  12720536.0
#
#            Short text for inspection object        Order  Vendor Batch  \
# 0  BCH LE/SI-1.00 CB/HB/B-1.00 P2A =1036077  108114882.0           NaN
# 1  BCH LE/SI-1.00 CB/HB/B-1.00 P2A =1036077  108114882.0           NaN
# ...

# %%
Material=uploaded2.Material.value_counts()
Material
# Out:
# 1172919    185
# 1290229    179
# 1688915    138
# 1172898    138
# 1206154    132
# 1418373    120
# 1521498     99
# 2102311     72
# 1036590     62
# 1002373     58
# 1006884     56
# 1875468     50
# 1399322      9
# Name: Material, dtype: int64

# %%
df_master = uploaded2.merge(uploaded,
                   on = "Material",
                   how = 'inner')
df_master
# Out:
#         Purchasing Document   System Status  Short-term charac.  \
# 0                       NaN  INSP RREC SPRQ                   2
# 1                       NaN  INSP RREC SPRQ                   2
# 2                       NaN  INSP RREC SPRQ                   2
# 3                       NaN  INSP RREC SPRQ                   2
# 4                       NaN  INSP RREC SPRQ                   2
# ...                     ...             ...                 ...
# 187030                  NaN  UD   ICCO STUP                   0
# 187031                  NaN  UD   ICCO STUP                   0
# 187032                  NaN  UD   ICCO STUP                   0
# 187033                  NaN  UD   ICCO STUP                   0
# 187034                  NaN  UD   ICCO STUP                   0
#
#         Inspection Lot  Material Document  Material       Batch  \
# 0          40003260779       6.026331e+09   1172919  12752330.0
# 1          40003260779       6.026331e+09   1172919  12752330.0
# ...

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187035 entries, 0 to 187034
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Purchasing Document               0 non-null       float64
#  1   System Status                     187035 non-null  object
#  2   Short-term charac.                187035 non-null  int64
#  3   Inspection Lot                    187035 non-null  int64
#  4   Material Document                 92433 non-null   float64
#  5   Material                          187035 non-null  int64
#  6   Batch                             186093 non-null  float64
#  7   Short text for inspection object  187035 non-null  object
#  8   Order                             186987 non-null  float64
#  9   Vendor Batch                      0 non-null       float64
#  10  Storage Location                  92433 non-null   float64
# ...

# %% [markdown]
# # New section

# %% [markdown]
# # New section
